# %% [markdown]
# # Planetary examples for ipyleaflet

# %% [markdown]
#  ### Resources
#  - ipyleaflet : https://ipyleaflet.readthedocs.io/en/latest/index.html
#
# WMS server used below:
#  - Lunaserv (WMS) : http://lunaserv.lroc.asu.edu/about.html
#   - How to easily see tons of Lunaserv layers in QGIS: http://lunaserv.lroc.asu.edu/getting_started_with_lunaserv_and_qgis.pdf
#
# JPL's tile server acting odd in ipyleaflet (see below):
#  - NASA planetary tiled services (Treks) : https://api.nasa.gov/api.html#trek
#   - Treks viewer : https://trektiles.jpl.nasa.gov/trektiles/demo/home5/
#
# Our USGS Mapserv not working with ipyleaflet...(need to figure that out also! - both should work)
#  - Astrogeology WMS layers thread : http://planetarygis.blogspot.com/2014/09/tips-to-interact-with-astros-wms-maps.html
#    - Planetary Viewer using Cesium (using WMS layers) :  https://cesiumjs.org/demos/planetarysurfaceportal/

# %% [markdown]
# ### Lunar ipyleaflet viewer

# %%
from ipyleaflet import Map, WMSLayer, LayersControl

wmsLayer = WMSLayer(
    url='https://planetarymaps.usgs.gov/cgi-bin/mapserv?map=/maps/mars/mars_simp_cyl.map',
    layers='MOLA_THEMIS_blend',
    name='MOLA THEMIS Blend (MDIM2.1)',
    crs='EPSG4326'
)

mars_map = Map(layers=(wmsLayer, ), center=(0, 0), zoom=4, crs='EPSG4326')
mars_map.add_control(LayersControl())
mars_map
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
#Took screen shot of live map, had to make a fake map for my Gist
from IPython.display import Image
Image(filename='moon_ipyleaflet.JPG')

# %% [markdown]
# ### Mars ipyleaflet viewer

# %%
from ipyleaflet import Map, WMSLayer, LayersControl

#WMS layer from lunaserv, ASU
MDIM21 = WMSLayer(
    url='http://webmap.lroc.asu.edu/',
    layers='mars_viking_mdim2.1',
    name='mars_viking_mdim2.1',
    attribution="ASU/NASA"
)

#WMS layer from lunaserv, ASU
MOLA_THEMIS = WMSLayer(
    url='http://webmap.lroc.asu.edu/',
    layers='mars_thm_dirmola_100m_v0_1',
    name='MOLA over THEMIS IR Day',
    attribution="ASU/NASA"
)

marsmap = Map(layers=(MOLA_THEMIS, MDIM21, ), center=(0, 0), zoom=4)
marsmap.add_control(LayersControl())
marsmap
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
#Took screen shot of live map, had to make a fake map for my Gist
from IPython.display import Image
Image(filename='mars_ipyleaflet.JPG')
